% %%
%% Info
% Example 5.1 : 3D Linear Advection in tensor-train format
% Developer   : M. Engin Danis
% Notes       :
% It is recommended to run this script on terminal:
% (1) do: export TTWENOLIB=/path/of/WENO-paper
% (2) do: matlab -nodesktop -nojvm -nosplash -nodisplay -singleCompThread -r "try, run('Ex1_TT.m'); catch err, disp(getReport(err)); end;exit;"

addpath(genpath('../../../../matlab/WENO/src/tt/'))
addpath(genpath('../../../../matlab/WENO/src/misc/'))
addpath(genpath('../../../../matlab/WENO/utils/'))
addpath(genpath('../../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../../matlab/utils/ttfunc/'))

clear; clc; close all;

% %%
%% set number of grid levels 
num_lvls = 4;
 
%% Input parameters to ttFDWenoSolver.m (Nx, Ny, Nz will be set later)
Tfinal    = 0.1;                                  % Final Time of the simulation   
dtOption  = 2;                                    % Time Stepping Option           
CFL       = 1;                                    % CFL Number for adaptive time-stepping
Neq       = 1;                                    % Number of equations 
N1d       = 5*(2.^linspace(1,num_lvls,num_lvls)); % Number of cells in each direction
Lx        = 1;                                    % Domain length in the x-direction 
Ly        = 1;                                    % Domain length in the y-direction 
Lz        = 1;                                    % Domain length in the z-direction 
funFlux   = @F_linearWave;                        % Function handle for flux vector computation in each direction 
funEig    = @Eig_linearWave;                      % Function handle for computing eigenvalues of flux jacobian    
funInit   = @Q0;                                  % Function handle for initial conditions                        
funBC     = @BCperiodic;                          % Function handle for boundary conditions                       
isSource  = false;                                % Flag to use user-defined "sourceTerm.m" to handle source terms    
gam       = [];                                   % Ratio of specific heats (not used here, so it is left empty)
eps_tt    = 1e-14;                                % Initial tolerance for tt trunctation                                   
eps_cross = 1e-14;                                % Initial tolerance for tt cross interpolation                           
C_eps     = 500;                                  % Empricial coefficient in Eq. (35) of the TT-WENO paper by Danis et al. 
isConsErr = false;                                % Flag to calculate the local conservation error

%% For spead measurements, make sure to use only a single thread
maxNumCompThreads(1); 
fprintf("Using %d threads\n",maxNumCompThreads);

%% Setup library paths
%restoredefaultpath;
%run(getenv("TTWENOLIB")+"/tt_setup.m");
%% Setup equation specific path for flux and eigenvalue routines 
%addpath(fdwenolib.tt+"/equations/LinearWave3d");

%% Setup arrays for error and speed measurement reporting
L1error   = zeros(Neq,num_lvls);
L2error   = zeros(Neq,num_lvls);
Linferror = zeros(Neq,num_lvls);
CPUtime   = zeros(num_lvls,1);
N         = zeros(num_lvls,3); 

%% Set the path where results will be written. This directory will be created if needed
resultPath = "results";
if exist(resultPath, 'dir')
    cmd = "rm -rf "+resultPath;
    system(cmd);
end
mkdir(resultPath);

%% Run simulations for all grid levels
for lvl=1:length(N1d)
    %
    Nx = N1d(lvl);
    Ny = Nx;
    Nz = Nx;
    %
    N(lvl,:) = [Nx Ny Nz];
    %
    fprintf("%s",repelem("-",70));fprintf("\n");
    fprintf("Starting to solve grid level=%d with Nx=%d Ny=%d Nz=%d\n",lvl,Nx,Ny,Nz);
    fprintf("%s",repelem("-",70));fprintf("\n");
    %
    data = ttFDWenoSolver(Tfinal, dtOption, CFL, Neq, Nx, Ny, Nz, Lx, Ly, Lz,...
                          funFlux, funEig, funInit, funBC, isSource, gam, ...
                          eps_tt, eps_cross, C_eps, isConsErr);
    % Set time spent by the solver
    CPUtime(lvl) = data.CPUtime;
    %% Error calculation
    Q  = data.tt.Q;              % numerical result (tt form)
    Qe = solExact(data, Tfinal); % exact solution (tt form)
    Qe = remove_ghost(Qe,Neq);
    %
    vol = Lx*Ly*Lz/(Nx*Ny*Nz);
    h32 = sqrt(vol);
    %
    for eq=1:Neq
        %
        dQ = abs(full(Q{eq}-Qe{eq}));
        %
        L1error(eq,lvl)   = sum(dQ)*vol;
        %
        L2error(eq,lvl)   = norm(dQ)*h32;
        %
        Linferror(eq,lvl) = max(dQ);
        %
    end
    %
    save_errors(resultPath+"/L1.txt",L1error(:,1:lvl));
    save_errors(resultPath+"/L2.txt",L2error(:,1:lvl));
    save_errors(resultPath+"/Linf.txt",Linferror(:,1:lvl));
    save_errors(resultPath+"/time.txt",CPUtime(1:lvl));
    %
    save_ranks(resultPath+"/ranks-lvl="+lvl+".txt",data.tt.rank);
    %
    print_errors(1,L1error(:,1:lvl),"L1",N(1:lvl,:));
    print_errors(1,L2error(:,1:lvl),"L2",N(1:lvl,:));
    print_errors(1,Linferror(:,1:lvl),"Linf",N(1:lvl,:));
    %
    fprintf("\n");
end
%
save_error_table(resultPath+"/Table-L1.txt",L1error,"L1",N);
save_error_table(resultPath+"/Table-L2.txt", L2error,"L2",N);
save_error_table(resultPath+"/Table-Linf.txt",Linferror,"Linf",N);
%
fprintf("\n ------ ------------\n");
fprintf(" level | CPUtime (s)\n");
fprintf(" ------ ------------\n");
fprintf(" %5d | %10.4e\n",[(1:length(CPUtime))' CPUtime]');
fprintf("\n");
% Out:
% Using 1 threads
% ----------------------------------------------------------------------
% Starting to solve grid level=1 with Nx=10 Ny=10 Nz=10
% ----------------------------------------------------------------------
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          0    0.00000e+00    2.15443e-02    0.00000e+00  1.0000e-03 | F-norm :  1.43e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (4,4)
%                       rk-stage: 3                                   | (r1,r2) :     (4,4)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          1    2.15443e-02    2.15443e-02    0.00000e+00  1.0000e-03 | F-norm :  1.43e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (5,5)
%                       rk-stage: 2                                   | (r1,r2) :     (5,5)
%                       rk-stage: 3                                   | (r1,r2) :     (5,5)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          2    4.30887e-02    2.15443e-02    0.00000e+00  1.0000e-03 | F-norm :  1.42e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (5,5)
%                       rk-stage: 2                                   | (r1,r2) :     (5,5)
%                       rk-stage: 3                                   | (r1,r2) :     (4,4)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          3    6.46330e-02    2.15443e-02    0.00000e+00  1.0000e-03 | F-norm :  1.42e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (5,5)
%                       rk-stage: 2                                   | (r1,r2) :     (5,5)
%                       rk-stage: 3                                   | (r1,r2) :     (5,5)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          4    8.61774e-02    1.38226e-02    0.00000e+00  1.0000e-03 | F-norm :  1.41e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (5,5)
%                       rk-stage: 2                                   | (r1,r2) :     (5,5)
%                       rk-stage: 3                                   | (r1,r2) :     (5,5)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          5    1.00000e-01    0.00000e+00    0.00000e+00  1.0000e-03 | F-norm :  1.41e+00
% ........................................................................................
%                                                                     | (r1,r2):     (5,5)
%
%
% L1 errors:
%  |  10x10x10  |
%  |------------|
%  | 1.325e-02  |
%
%
% L2 errors:
%  |  10x10x10  |
%  |------------|
%  | 1.487e-02  |
%
%
% Linf errors:
%  |  10x10x10  |
%  |------------|
%  | 2.193e-02  |
%
% ----------------------------------------------------------------------
% Starting to solve grid level=2 with Nx=20 Ny=20 Nz=20
% ----------------------------------------------------------------------
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          0    0.00000e+00    6.78604e-03    0.00000e+00  2.2097e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                        | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          2    1.35721e-02    6.78604e-03    0.00000e+00  2.2099e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :                                     | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          4    2.71442e-02    6.78604e-03    0.00000e+00  2.2101e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                              -----------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          6    4.07163e-02    6.78604e-03    0.00000e+00  2.2103e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% --------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          8    5.42884e-02    6.78604e-03    0.00000e+00  2.2105e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          9    6.10744e-02    6.78604e-03    0.00000e+00  2.2106e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         10    6.78604e-02    6.78604e-03    0.00000e+00  2.2107e-04 | F-norm :  1.05e+00
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% -------------------------------------------
% IOPub data rate exceeded.
% The Jupyter server will temporarily stop sending output
% to the client in order to avoid crashing it.
% To change this limit, set the config variable
% `--ServerApp.iopub_data_rate_limit`.
%
% Current values:
% ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
% ServerApp.rate_limit_window=3.0 (secs)
% ----
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          0    0.00000e+00    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ............................................................................        | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          3    2.01978e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          4    2.69304e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                       | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          7    4.71283e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%          8    5.38609e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% --------------------------------Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         11    7.40587e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         12    8.07913e-03    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ---------------............................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         18    1.21187e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         19    1.27920e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                  | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         22    1.48117e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         23    1.54850e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         24    1.61583e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                  ------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         26    1.75048e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)
% IOPub data rate exceeded.
% The Jupyter server will temporarily stop sending output
% to the client in order to avoid crashing it.
% To change this limit, set the config variable
% `--ServerApp.iopub_data_rate_limit`.
%
% Current values:
% ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
% ServerApp.rate_limit_window=3.0 (secs)
% -------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         91    6.12667e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         92    6.19400e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3          (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         94    6.32865e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%         95    6.39598e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ---------------------------------------------------------------------------------------------------------
%        100    6.73261e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        101    6.79993e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        102    6.86726e-02    6.73261e-04              rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        105    7.06924e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        106    7.13656e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%      (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        109    7.33854e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        110    7.40587e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                            --------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        113    7.60785e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% ----------------------------------------------------------------------------------------
%        114    7.67517e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)   ------------------------------------------------------------
%        117    7.87715e-02    6.73261e-04    0.00000e+00  2.1579e-07 | F-norm :  7.88e-01
% ........................................................................................
%                       rk-stage: 1                                   | (r1,r2) :     (2,2)
%                       rk-stage: 2                                   | (r1,r2) :     (2,2)
%                       rk-stage: 3                                   | (r1,r2) :     (2,2)
%
% ----------------------------------------------------------------------------------------
%  Time Step       Time (s)         dt (s)  max_eig (m/s)         eps | TT_info:         u
% -----------------
% IOPub data rate exceeded.
% The Jupyter server will temporarily stop sending output
% to the client in order to avoid crashing it.
% To change this limit, set the config variable
% `--ServerApp.iopub_data_rate_limit`.
%
% Current values:
% ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
% ServerApp.rate_limit_window=3.0 (secs)
