% %%
addpath(genpath('../../../matlab/Linear-STSC/src/'))
addpath(genpath('../../../matlab/utils/chebfun/'))
addpath(genpath('../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../matlab/utils/ttfunc/'))
close all; clear;

% %%
%% load test cases
testname = 'ConstantCoeff'; %example 1 - constant coefficient
% testname = 'VariableCoeff'; %example 2 - variable coefficient
% testname = 'NonSmooth'; %example 3 - variable coefficient

fprintf('Working on testcase %s \n',testname);
load(sprintf('../testcases/%s.mat',testname));

%domain
a = -1;
b = 1;

tol = 1e-12;
type='Chebyshev';
savefilename = sprintf('../plot_data/fullgrid_ST_SP_%s.mat',testname);
%% now the time step is the same as space step
Ns = [4,6,8];
R = cell(numel(Ns),1);

for i = 1:numel(Ns)
  tic
  n = Ns(i);
  TN = n;
  SN = n-1;
  N1 = SN+1;

  %%
  [ttsol, Ctt] = fg_ST_Spectral_3D_Solver(testcase,SN,type,tol,a,b);
  tt_time = toc;
  %% check the error
  exacttt = amen_cross(Ctt, @(x) cross_fun_nD(x,testcase.exactfn),tol);
  exacttt = tt_get_inner(exacttt,{2:N1,2:N1-1,2:N1-1,2:N1-1});
  exacttt = full(exacttt);

  Err = norm(ttsol-exacttt)/norm(exacttt);
  fprintf('Solution Error between TT and matrix= %.2e \n',...
    Err);

  fprintf('Elapsed time of qtt = %.2f seconds \n', tt_time)
  % fprintf('Compression Ratio of ttsol = %.2e \n', compress_ratio_tt(ttsol));


  %% collect results
  c.sol = ttsol;
  c.err = Err;
  c.time = tt_time;
  % c.amensolvedata = amensolvedata;
  R{i} = c;

  save(savefilename,'Ns','R','tol','testcase','type');
end
% Out:
% Working on testcase ConstantCoeff
% =amen_cross= swp=1, max_dx=6.152e+00, max_rank=3, #ifun_evals=0, #ffun_evals=348
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=700
% =amen_cross= swp=1, max_dx=4.453e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=3.416e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=4.482e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=4.871e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=1.693e+01, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=4.497e-05, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=2.103e-14, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=6.813e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=1.713e-14, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% =amen_cross= swp=1, max_dx=5.238e+00, max_rank=4, #ifun_evals=0, #ffun_evals=456
% =amen_cross= swp=2, max_dx=6.818e-03, max_rank=6, #ifun_evals=0, #ffun_evals=1144
% =amen_cross= swp=3, max_dx=3.245e-15, max_rank=7, #ifun_evals=0, #ffun_evals=1936
% =amen_cross= swp=4, max_dx=3.075e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2168
% =amen_cross= swp=5, max_dx=3.229e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2360
% =amen_cross= swp=1, max_dx=7.252e+00, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=9.140e-05, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=4.342e-15, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=2.848e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=2.556e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% Solution Error between TT and matrix= 5.83e-04
% Elapsed time of qtt = 1.43 seconds
% =amen_cross= swp=1, max_dx=6.022e+00, max_rank=3, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=2, max_dx=1.071e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1230
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1272
% =amen_cross= swp=1, max_dx=7.842e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1164
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1206
% =amen_cross= swp=1, max_dx=8.515e+00, max_rank=3, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1254
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1296
% =amen_cross= swp=1, max_dx=7.568e+00, max_rank=3, #ifun_evals=0, #ffun_evals=570
% =amen_cross= swp=2, max_dx=1.538e-15, max_rank=3, #ifun_evals=0, #ffun_evals=1122
% =amen_cross= swp=3, max_dx=1.804e-15, max_rank=1, #ifun_evals=0, #ffun_evals=1170
% =amen_cross= swp=1, max_dx=6.224e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1164
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1206
% =amen_cross= swp=1, max_dx=2.308e+01, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=2.073e-03, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=1.488e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=1.629e-14, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=1.121e-14, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% =amen_cross= swp=1, max_dx=6.878e+00, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=9.979e-05, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=9.661e-15, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=3.320e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=4.221e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% =amen_cross= swp=1, max_dx=5.770e+00, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=2.447e-04, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=9.017e-15, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=4.114e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=4.819e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% Solution Error between TT and matrix= 8.98e-07
% Elapsed time of qtt = 0.20 seconds
% =amen_cross= swp=1, max_dx=6.840e+00, max_rank=3, #ifun_evals=0, #ffun_evals=720
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1288
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1344
% =amen_cross= swp=1, max_dx=6.985e+00, max_rank=3, #ifun_evals=0, #ffun_evals=720
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1288
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1344
% =amen_cross= swp=1, max_dx=7.545e+00, max_rank=3, #ifun_evals=0, #ffun_evals=896
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1640
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1696
% =amen_cross= swp=1, max_dx=8.493e+00, max_rank=3, #ifun_evals=0, #ffun_evals=856
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1552
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1608
% =amen_cross= swp=1, max_dx=8.403e+00, max_rank=3, #ifun_evals=0, #ffun_evals=856
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1552
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1608
% =amen_cross= swp=1, max_dx=2.429e+01, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=9.293e-05, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=2.358e-14, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=1.676e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=1.756e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% =amen_cross= swp=1, max_dx=6.571e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=1.439e-02, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=2.767e-14, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=4.359e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=4.122e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% =amen_cross= swp=1, max_dx=6.410e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=9.033e-04, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=3.023e-14, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=8.107e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=4.279e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% Solution Error between TT and matrix= 9.19e-10
% Elapsed time of qtt = 0.74 seconds
