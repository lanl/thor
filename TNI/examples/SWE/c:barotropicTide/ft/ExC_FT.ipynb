% %% [markdown]
% <h1>
% High-order Tensor-Train Finite Volume Methods for Shallow Water Equations
% </h1>

% %% [markdown]
% M. Engin Danis, Duc P. Truong, Derek DeSantis, Jeremy Lilly, Mark R. Petersen, Kim Ø. Rasmussen, and Boian S. Alexandrov

% %% [markdown]
% https://doi.org/10.1175/MWR-D-24-0165.1

% %%
%% Info
% Example C   : Barotropic Tide in full-tensor format
% Developer   : M. Engin Danis
% Notes       :
% It is recommended to run this script on terminal:
% (1) do: export TTSWELIB=/path/of/SWE-paper
% (2) do: matlab -nodesktop -nojvm -nosplash -nodisplay -singleCompThread -r "try, run('ExC_FT.m'); catch err, disp(getReport(err)); end;exit;"
addpath(genpath('../../../../matlab/SWE/src/ft/'))
addpath(genpath('../../../../matlab/SWE/src/misc/'))
addpath(genpath('../../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../../matlab/utils/ttfunc/'))

clear; clc; close all;

% %%
%% set the list of reconstruction schemes
ReconList = {"Upwind3", "Upwind5", "WENO5"};

%% set number of grid levels 
num_lvls = 2; %5 for full run

%% Input parameters to ftFVSWEsolver.m (Nx, Ny, CFL, Recon will be set later)
SWEtype    = "linear";                              % Shallow Water Equations (SWEs) type
Tfinal     = 1800;                                  % Final Time of the simulation
dtOption   = 2;                                     % Time Stepping Option
N1d        = 10*(2.^linspace(1,num_lvls,num_lvls)); % Number of cells in each direction
Lx         = 25e4;                                  % Domain length in the x-direction
Ly         = 25e4;                                  % Domain length in the y-direction
H          = 200;                                   % Mean depth
gacc       = 10;                                    % Acceleration of gravity
Coriolis_f = 1e-4;                                  % Coriolis parameter
funInit    = @Q0;                                   % Function handle for initial conditions
funBC      = @BC;                                   % Function handle for boundary conditions 
Ref.L      = 25e4;                                  % Reference length scale
Ref.H      = 0.2;                                   % Reference depth scale
isManuf    = false;                                 % Flag to use user-defined "manuf.m" to handle manufactured solutions terms
isConsErr  = false;                                 % Flag to calculate conservation errors

%% Reference velocity scale is calculated as below
eta   = 0.2;
kx    = 4.5*pi/Lx;
C2    = 200*gacc;
k     = sqrt(2)*kx;
om    = sqrt(C2*k^2+Coriolis_f^2);
Ref.U = gacc*eta*kx*om/(om^2-Coriolis_f^2);

%% For spead measurements, make sure to use only a single thread
maxNumCompThreads(1); 
fprintf("Using %d threads\n",maxNumCompThreads);

% Set number of equations
Neq = 3;

%% Setup arrays for error and speed measurement reporting
L1error   = zeros(Neq,num_lvls);
L2error   = zeros(Neq,num_lvls);
Linferror = zeros(Neq,num_lvls);
CPUtime   = zeros(num_lvls,1);
N         = zeros(num_lvls,2);

%% Set the path where results will be written. This directory will be created if needed
resultPath = "results";
if exist(resultPath, 'dir')
    cmd = "rm -rf "+resultPath;
    system(cmd);
end
mkdir(resultPath);

%% Run simulations for all reconstruction methods
for recon_idx = 1:length(ReconList)
    %% Get the reconstruction method type
    Recon = ReconList{recon_idx};

    %% Set the path where specific results for this reconstruction will be written 
    resultPathRecon = resultPath + "/" + Recon;
    if exist(resultPathRecon, 'dir')
        cmd = "rm -rf "+resultPathRecon;
        system(cmd);
    end
    mkdir(resultPathRecon);

    %% Set the CFL number for this reconstruction method
    if(Recon=="Upwind3")
        CFL = 0.00025;
    else
        CFL = 0.0005;
    end

    %% Run simulations for all grid levels
    for lvl=1:length(N1d)
        %
        Nx = N1d(lvl);
        Ny = Nx;
        %
        N(lvl,:) = [Nx Ny];
        %
        fprintf("%s",repelem("-",70));fprintf("\n");
        fprintf("Starting to solve grid level=%d with Nx=%d Ny=%d\n",lvl,Nx,Ny);
        fprintf("%s",repelem("-",70));fprintf("\n");
        %
        data = ftFVSWEsolver(SWEtype, Tfinal, dtOption, CFL, Nx, Ny, Lx, Ly, H, gacc, ...
                             Coriolis_f, funInit, funBC, Recon, Ref, isManuf, isConsErr);
        % Set time spent by the solver
        CPUtime(lvl) = data.CPUtime;
        %% Error calculation
        Q  = data.Q;                                                      % numerical result
        Qe = applyQuadrature(@solExact,data,Tfinal/data.ref.t)/data.vol;  % exact solution
        %
        % Dimensionalize Qe
        %
        Qe(1,:,:) = Qe(1,:,:) * data.Qref(1);
        Qe(2,:,:) = Qe(2,:,:) * data.Qref(2);
        Qe(3,:,:) = Qe(3,:,:) * data.Qref(3);
        %
        vol = Lx*Ly/(Nx*Ny);
        h32 = sqrt(vol);
        %
        % Note: L1 and L2 error values might seem large due to very large Lx and Ly values.
        %       However, the convergence rate will recover the formal order of the underlying scheme.
        %       So, scaling them by Lx*Ly will produce more familiar error value (optional). 
        %       However, for testing purposes, L1 and L2 errors are calculated as below.
        %
        for eq=1:Neq
            %
            dQ = abs(Q(eq,:)-Qe(eq,:));
            %
            L1error(eq,lvl)   = sum(dQ)*vol;
            %
            L2error(eq,lvl)   = norm(dQ)*h32;
            %
            Linferror(eq,lvl) = max(dQ);
            %
        end
        %
        save_errors(resultPathRecon+"/L1.txt",L1error(:,1:lvl));
        save_errors(resultPathRecon+"/L2.txt",L2error(:,1:lvl));
        save_errors(resultPathRecon+"/Linf.txt",Linferror(:,1:lvl));
        save_errors(resultPathRecon+"/time.txt",CPUtime(1:lvl));
        %
        print_errors(1,L1error(:,1:lvl),"L1",N(1:lvl,:));
        print_errors(1,L2error(:,1:lvl),"L2",N(1:lvl,:));
        print_errors(1,Linferror(:,1:lvl),"Linf",N(1:lvl,:));
        %
        fprintf("\n");
    end
    %
    save_error_table(resultPathRecon+"/Table-L1.txt",L1error,"L1",N);
    save_error_table(resultPathRecon+"/Table-L2.txt", L2error,"L2",N);
    save_error_table(resultPathRecon+"/Table-Linf.txt",Linferror,"Linf",N);
    %
    fprintf("\n ------ ------------\n");
    fprintf(" level | CPUtime (s)\n");
    fprintf(" ------ ------------\n");
    fprintf(" %5d | %10.4e\n",[(1:length(CPUtime))' CPUtime]');
    fprintf("\n");
    %
end
% Out:
% Using 1 threads
% ----------------------------------------------------------------------
% Starting to solve grid level=1 with Nx=20 Ny=20
% ----------------------------------------------------------------------
% Time Step= 0	 Time=0.00000	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 1	 Time=98.78257	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 2	 Time=197.56514	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 3	 Time=296.34771	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 4	 Time=395.13028	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 5	 Time=493.91285	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 6	 Time=592.69542	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 7	 Time=691.47799	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 8	 Time=790.26056	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 9	 Time=889.04313	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 10	 Time=987.82570	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 11	 Time=1086.60827	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 12	 Time=1185.39084	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 13	 Time=1284.17341	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 14	 Time=1382.95598	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 15	 Time=1481.73856	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 16	 Time=1580.52113	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 17	 Time=1679.30370	 dt=9.87826e+01	 max_eig=4.47e+01
% Time Step= 18	 Time=1778.08627	 dt=2.19137e+01	 max_eig=4.47e+01
% Time Step= 19	 Time=1800.00000	 dt=0.00000e+00	 max_eig=4.47e+01
%
%
% L1 errors:
%  |   20x20    |
%  |------------|
%  | 3.479e+08  |
%  | 3.693e+08  |
%  | 3.946e+06  |
%
%
% L2 errors:
%  |   20x20    |
%  |------------|
%  | 1.918e+03  |
%  | 1.671e+03  |
%  | 1.936e+01  |
%
%
% Linf errors:
%  |   20x20    |
%  |------------|
%  | 2.322e-02  |
%  | 1.063e-02  |
%  | 1.989e-04  |
%
% ----------------------------------------------------------------------
% Starting to solve grid level=2 with Nx=40 Ny=40
% ----------------------------------------------------------------------
% Time Step= 0	 Time=0.00000	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 1	 Time=49.39129	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 2	 Time=98.78257	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 3	 Time=148.17386	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 4	 Time=197.56514	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 5	 Time=246.95643	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 6	 Time=296.34771	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 7	 Time=345.73900	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 8	 Time=395.13028	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 9	 Time=444.52157	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 10	 Time=493.91285	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 11	 Time=543.30414	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 12	 Time=592.69542	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 13	 Time=642.08671	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 14	 Time=691.47799	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 15	 Time=740.86928	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 16	 Time=790.26056	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 17	 Time=839.65185	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 18	 Time=889.04313	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 19	 Time=938.43442	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step= 20	 Time=987.82570	 dt=4.93913e+01	 max_eig=4.47e+01
% Time Step=
 dt=2.68137e+01	 max_eig=4.47e+01
% Time Step= 66	 Time=1769.70518	 dt=2.68137e+01	 max_eig=4.47e+01
% Time Step= 67	 Time=1796.51890	 dt=3.48110e+00	 max_eig=4.47e+01
% Time Step= 68	 Time=1800.00000	 dt=0.00000e+00	 max_eig=4.47e+01
%
%
% L1 errors:
%  |   20x20    |
%  |------------|
%  | 4.287e+07  |
%  | 3.684e+07  |
%  | 4.087e+05  |
%
%
% L2 errors:
%  |   20x20    |
%  |------------|
%  | 2.283e+02  |
%  | 1.666e+02  |
%  | 2.026e+00  |
%
%
% Linf errors:
%  |   20x20    |
%  |------------|
%  | 2.643e-03  |
%  | 1.054e-03  |
%  | 2.201e-05  |
%
% ----------------------------------------------------------------------
% Starting to solve grid level=2 with Nx=40 Ny=40
% ----------------------------------------------------------------------
% Time Step= 0	 Time=0.00000	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 1	 Time=8.44579	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 2	 Time=16.89158	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 3	 Time=25.33737	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 4	 Time=33.78316	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 5	 Time=42.22895	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 6	 Time=50.67475	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 7	 Time=59.12054	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 8	 Time=67.56633	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 9	 Time=76.01212	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 10	 Time=84.45791	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 11	 Time=92.90370	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 12	 Time=101.34949	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 13	 Time=109.79528	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 14	 Time=118.24107	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 15	 Time=126.68686	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 16	 Time=135.13266	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 17	 Time=143.57845	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 18	 Time=152.02424	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 19	 Time=160.47003	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 20	 Time=168.91582	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 21	 Time=177.36161	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 22	 Time=185.80740	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 23	 Time=194.25319	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 24	 Time=202.69898	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 25	 Time=211.14477	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 26	 Time=219.59057	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 27	 Time=228.03636	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 28	 Time=236.48215	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 29	 Time=244.92794	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 30	 Time=253.37373	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 31	 Time=261.81952	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 32	 Time=270.26531	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 33	 Time=278.71110	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 34	 Time=287.15689	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 35	 Time=295.60268	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 36	 Time=304.04847	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 37	 Time=312.49427	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 38	 Time=320.94006	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 39	 Time=329.38585	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 40	 Time=337.83164	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 41	 Time=346.27743	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 42	 Time=354.72322	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 43	 Time=363.16901	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 44	 Time=371.61480	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 45	 Time=380.06059	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 46	 Time=388.50638	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 47	 Time=396.95218	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 48	 Time=405.39797	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 49	 Time=413.84376	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 50	 Time=422.28955	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 51	 Time=430.73534	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 52	 Time=439.18113	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 53	 Time=447.62692	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 54	 Time=456.07271	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 55	 Time=464.51850	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 56	 Time=472.96429	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 57	 Time=481.41008	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 58	 Time=489.85588	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 59	 Time=498.30167	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 60	 Time=506.74746	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 61	 Time=515.19325	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 62	 Time=523.63904	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 63	 Time=532.08483	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 64	 Time=540.53062	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 65	 Time=548.97641	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 66	 Time=557.42220	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 67	 Time=565.86799	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 68	 Time=574.31379	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 69	 Time=582.75958	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 70	 Time=591.20537	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 71	 Time=599.65116	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 72	 Time=608.09695	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 73	 Time=616.54274	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 74	 Time=624.98853	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 75	 Time=633.43432	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 76	 Time=641.88011	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 77	 Time=650.32590	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 78	 Time=658.77170	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 79	 Time=667.21749	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 80	 Time=675.66328	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 81	 Time=684.10907	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 82	 Time=692.55486	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 83	 Time=701.00065	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 84	 Time=709.44644	 dt=8.44579e+00	 max_eig=4.47e+01
% Time Step= 85	 Time=717.89223	 dt=8.44579e+00	 max_eig=4.47e+01
% IOPub message rate exceeded.
% The Jupyter server will temporarily stop sending output
% to the client in order to avoid crashing it.
% To change this limit, set the config variable
% `--ServerApp.iopub_msg_rate_limit`.
%
% Current values:
% ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
% ServerApp.rate_limit_window=3.0 (secs)
