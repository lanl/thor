% %%
addpath(genpath('../../../matlab/Linear-STSC/src/'))
addpath(genpath('../../../matlab/Non-linear-STSC/src/'))
addpath(genpath('../../../matlab/utils/chebfun/'))
addpath(genpath('../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../matlab/utils/ttfunc/'))

close all; clear;

% %%
testname = "../testcases/Burger3D";

fprintf('Working on testcase %s \n',testname);
load(sprintf('./%s.mat',testname));
%%
a = 0;
b = 6;
tol = 1e-5;
Newtoneps = 1e-6;
tempname = split(testname,'/');
savefilename = sprintf('../plot_data/fg_%s.mat', tempname(end));
%% now the time step is the same as space step
Ns = [4:2:8];
R = cell(numel(Ns),1);
for i = [1:numel(Ns)]
  tic
  n = Ns(i);
  SN = n-1;
  N1 = SN+1;
  %%
  fprintf('************************************\n')
  fprintf('n = %d \n',n);
  %%
  [fgsol, NewtonIter, Ctt] = ...
    FG_3D_Burger_Solver(testcase,SN,tol,Newtoneps,a,b);
  tt_time = toc;
  %% check the error
  exacttt = amen_cross(Ctt, @(x) cross_fun_nD(x,testcase.exactfn),tol);
  exacttt = tt_get_inner(exacttt,{2:N1,2:N1-1,2:N1-1,2:N1-1});
  exacttt = full(exacttt);
  Err = norm(fgsol-exacttt)/norm(exacttt);
  fprintf('Solution Error between TT and matrix= %.2e \n',...
    Err);
  fprintf('Newton Iter = %d \n', NewtonIter);
  fprintf('Elapsed time of tt = %.2f seconds \n', tt_time)
  % fprintf('Compression Ratio of ttsol = %.2e \n', compress_ratio_tt(fgsol));
  %% collect results
  c.sol = fgsol;
  c.err = Err;
  c.time = tt_time;
  c.NewtonIter = NewtonIter;
  % c.amensolvedata = amensolvedata;
  R{i,1} = c;

  save(savefilename,'Ns','R','tol','testcase');
end
% Out:
% Working on testcase ../testcases/Burger3D
% Warning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)uWarning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)uWarning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)uWarning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)1Warning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)1Warning: Could not find appropriate function on path loading function handle /Users/dptruong/project/tt_space_time/nonlinear_spec_colloc/Burger_testcase.m>@(u)1
% ************************************
% n = 4
% =amen_cross= swp=1, max_dx=1.719e+00, max_rank=4, #ifun_evals=0, #ffun_evals=452
% =amen_cross= swp=2, max_dx=3.409e-15, max_rank=4, #ifun_evals=0, #ffun_evals=1096
% =amen_cross= swp=3, max_dx=4.052e-16, max_rank=2, #ifun_evals=0, #ffun_evals=1164
%
% ******** Newton iter = 1 ************
%
% apha = 1.00e+00
% u_err = Inf,  Fu_ratio = 1.98080e-02
% iter time = 0.00
%
% ******** Newton iter = 2 ************
%
% apha = 1.00e+00
% u_err = 3.67293e-02,  Fu_ratio = 4.96828e-05
% iter time = 0.00
%
% ******** Newton iter = 3 ************
%
% apha = 1.00e+00
% u_err = 7.72607e-05,  Fu_ratio = 7.61540e-11
% iter time = 0.00
% =amen_cross= swp=1, max_dx=1.713e+00, max_rank=4, #ifun_evals=0, #ffun_evals=428
% =amen_cross= swp=2, max_dx=3.347e-15, max_rank=4, #ifun_evals=0, #ffun_evals=1056
% =amen_cross= swp=3, max_dx=4.309e-16, max_rank=2, #ifun_evals=0, #ffun_evals=1124
% Solution Error between TT and matrix= 2.54e-01
% Newton Iter = 3
% Elapsed time of tt = 0.34 seconds
% ************************************
% n = 6
% =amen_cross= swp=1, max_dx=2.249e+00, max_rank=4, #ifun_evals=0, #ffun_evals=810
% =amen_cross= swp=2, max_dx=6.974e-02, max_rank=6, #ifun_evals=0, #ffun_evals=2292
% =amen_cross= swp=3, max_dx=6.627e-03, max_rank=8, #ifun_evals=0, #ffun_evals=4116
% =amen_cross= swp=4, max_dx=3.607e-04, max_rank=9, #ifun_evals=0, #ffun_evals=6090
% =amen_cross= swp=5, max_dx=2.154e-05, max_rank=11, #ifun_evals=0, #ffun_evals=8244
% =amen_cross= swp=6, max_dx=1.822e-06, max_rank=12, #ifun_evals=0, #ffun_evals=10542
% =amen_cross= swp=7, max_dx=2.900e-15, max_rank=10, #ifun_evals=0, #ffun_evals=11256
%
% ******** Newton iter = 1 ************
%
% apha = 1.00e+00
% u_err = Inf,  Fu_ratio = 5.59483e-02
% iter time = 0.07
%
% ******** Newton iter = 2 ************
%
% apha = 1.00e+00
% u_err = 4.04953e-02,  Fu_ratio = 7.31676e-04
% iter time = 0.08
%
% ******** Newton iter = 3 ************
%
% apha = 1.00e+00
% u_err = 9.81648e-04,  Fu_ratio = 2.86333e-05
% iter time = 0.06
%
% ******** Newton iter = 4 ************
%
% apha = 1.00e+00
% u_err = 2.84100e-05,  Fu_ratio = 1.26190e-06
% iter time = 0.05
%
% ******** Newton iter = 5 ************
%
% apha = 1.00e+00
% u_err = 1.37467e-06,  Fu_ratio = 6.45727e-08
% iter time = 0.04
% =amen_cross= swp=1, max_dx=1.965e+00, max_rank=4, #ifun_evals=0, #ffun_evals=804
% =amen_cross= swp=2, max_dx=5.255e-01, max_rank=6, #ifun_evals=0, #ffun_evals=2208
% =amen_cross= swp=3, max_dx=8.573e-03, max_rank=8, #ifun_evals=0, #ffun_evals=3984
% =amen_cross= swp=4, max_dx=7.062e-05, max_rank=10, #ifun_evals=0, #ffun_evals=6030
% =amen_cross= swp=5, max_dx=1.478e-06, max_rank=12, #ifun_evals=0, #ffun_evals=8292
% =amen_cross= swp=6, max_dx=4.932e-08, max_rank=10, #ifun_evals=0, #ffun_evals=9078
% =amen_cross= swp=7, max_dx=2.570e-15, max_rank=10, #ifun_evals=0, #ffun_evals=9672
% Solution Error between TT and matrix= 3.91e-02
% Newton Iter = 5
% Elapsed time of tt = 0.59 seconds
% ************************************
% n = 8
% =amen_cross= swp=1, max_dx=3.336e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=1.113e-01, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=5.206e-03, max_rank=8, #ifun_evals=0, #ffun_evals=6432
% =amen_cross= swp=4, max_dx=1.679e-03, max_rank=10, #ifun_evals=0, #ffun_evals=9840
% =amen_cross= swp=5, max_dx=2.086e-05, max_rank=12, #ifun_evals=0, #ffun_evals=13512
% =amen_cross= swp=6, max_dx=1.270e-06, max_rank=14, #ifun_evals=0, #ffun_evals=17632
% =amen_cross= swp=7, max_dx=2.437e-06, max_rank=12, #ifun_evals=0, #ffun_evals=18952
%
% ******** Newton iter = 1 ************
%
% apha = 1.00e+00
% u_err = Inf,  Fu_ratio = 2.95306e-02
% iter time = 0.88
%
% ******** Newton iter = 2 ************
%
% apha = 1.00e+00
% u_err = 2.57650e-02,  Fu_ratio = 3.91295e-04
% iter time = 0.94
%
% ******** Newton iter = 3 ************
%
% apha = 1.00e+00
% u_err = 5.84413e-04,  Fu_ratio = 1.05175e-05
% iter time = 0.92
%
% ******** Newton iter = 4 ************
%
% apha = 1.00e+00
% u_err = 1.23803e-05,  Fu_ratio = 3.37229e-07
% iter time = 0.86
% =amen_cross= swp=1, max_dx=2.807e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=8.296e-02, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=7.443e-03, max_rank=8, #ifun_evals=0, #ffun_evals=6432
% =amen_cross= swp=4, max_dx=2.391e-03, max_rank=9, #ifun_evals=0, #ffun_evals=9728
% =amen_cross= swp=5, max_dx=7.398e-05, max_rank=11, #ifun_evals=0, #ffun_evals=13224
% =amen_cross= swp=6, max_dx=7.272e-06, max_rank=13, #ifun_evals=0, #ffun_evals=17168
% =amen_cross= swp=7, max_dx=2.334e-06, max_rank=12, #ifun_evals=0, #ffun_evals=18456
% Solution Error between TT and matrix= 6.31e-03
% Newton Iter = 4
% Elapsed time of tt = 4.02 seconds
