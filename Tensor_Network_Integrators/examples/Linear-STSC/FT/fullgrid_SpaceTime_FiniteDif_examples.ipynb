% %%
addpath(genpath('../../../matlab/Linear-STSC/src/'))
addpath(genpath('../../../matlab/utils/chebfun/'))
addpath(genpath('../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../matlab/utils/ttfunc/'))
close all; clear;

% %%
%% load test cases
testname = 'ConstantCoeff'; %example 1 - constant coefficient
% testname = 'VariableCoeff'; %example 2 - variable coefficient
% testname = 'NonSmooth'; %example 3 - variable coefficient

fprintf('Working on testcase %s \n',testname);
load(sprintf('../testcases/%s.mat',testname));

%%
a = -1;
b = 1;
tol = 1e-13;
savefilename = sprintf('../plot_data/fullgrid_ST_FD_%s.mat', testname);

%% now the time step is the same as space step
Ns = [4,6,8];
R = cell(numel(Ns),1);

for i = 1:numel(Ns)
  tic
  n = Ns(i);
  TN = n;
  SN = n-1;
  N1 = SN+1;

  %%
  [fgsol, Ctt] = fg_ST_FD_FD_3D_Solver(testcase,TN,SN,tol,a,b);
  tt_time = toc;
  %% check the error
  exacttt = amen_cross(Ctt, @(x) cross_fun_nD(x,testcase.exactfn),tol);
  exacttt = tt_get_inner(exacttt,{2:TN,2:N1-1,2:N1-1,2:N1-1});
  exacttt = full(exacttt);
  Err = norm(fgsol-exacttt)/norm(exacttt);
  fprintf('Solution Error between TT and matrix= %.2e \n',...
    Err);

  fprintf('Elapsed time of qtt = %.2f seconds \n', tt_time)
  % fprintf('Compression Ratio of ttsol = %.2e \n', compress_ratio_tt(fgsol));


  %% collect results
  c.sol = fgsol;
  c.err = Err;
  c.time = tt_time;
  % c.amensolvedata = amensolvedata;
  R{i} = c;

  save(savefilename,'Ns','R','tol','testcase');
end
% Out:
% Working on testcase ConstantCoeff
% =amen_cross= swp=1, max_dx=5.503e+00, max_rank=3, #ifun_evals=0, #ffun_evals=348
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=664
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=692
% =amen_cross= swp=1, max_dx=5.367e+00, max_rank=3, #ifun_evals=0, #ffun_evals=308
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=592
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=620
% =amen_cross= swp=1, max_dx=4.334e+00, max_rank=3, #ifun_evals=0, #ffun_evals=348
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=664
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=692
% =amen_cross= swp=1, max_dx=3.594e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=6.015e+00, max_rank=3, #ifun_evals=0, #ffun_evals=348
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=664
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=692
% =amen_cross= swp=1, max_dx=1.487e+01, max_rank=4, #ifun_evals=0, #ffun_evals=452
% =amen_cross= swp=2, max_dx=2.632e-03, max_rank=6, #ifun_evals=0, #ffun_evals=1160
% =amen_cross= swp=3, max_dx=1.419e-14, max_rank=7, #ifun_evals=0, #ffun_evals=1964
% =amen_cross= swp=4, max_dx=1.262e-14, max_rank=5, #ifun_evals=0, #ffun_evals=2196
% =amen_cross= swp=5, max_dx=7.378e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2388
% =amen_cross= swp=1, max_dx=5.536e+00, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=4.314e-03, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=5.094e-15, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=3.538e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=5.192e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% =amen_cross= swp=1, max_dx=4.620e+00, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=2.290e-02, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=4.721e-15, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=2.439e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=5.198e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% Solution Error between TT and matrix= 1.71e-02
% Elapsed time of qtt = 0.72 seconds
% =amen_cross= swp=1, max_dx=8.262e+00, max_rank=3, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=2, max_dx=1.071e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1230
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1272
% =amen_cross= swp=1, max_dx=7.538e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1164
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1206
% =amen_cross= swp=1, max_dx=8.537e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1176
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1218
% =amen_cross= swp=1, max_dx=7.274e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1176
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1218
% =amen_cross= swp=1, max_dx=7.182e+00, max_rank=3, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1230
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1272
% =amen_cross= swp=1, max_dx=1.803e+01, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=7.175e-05, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=1.837e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=1.392e-14, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=2.459e-14, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% =amen_cross= swp=1, max_dx=5.898e+00, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=6.964e-04, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=1.062e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=5.334e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=5.414e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% =amen_cross= swp=1, max_dx=6.647e+00, max_rank=4, #ifun_evals=0, #ffun_evals=810
% =amen_cross= swp=2, max_dx=3.775e-02, max_rank=6, #ifun_evals=0, #ffun_evals=2292
% =amen_cross= swp=3, max_dx=1.336e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4044
% =amen_cross= swp=4, max_dx=5.038e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4506
% =amen_cross= swp=5, max_dx=5.975e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4866
% Solution Error between TT and matrix= 1.02e-02
% Elapsed time of qtt = 0.31 seconds
% =amen_cross= swp=1, max_dx=6.809e+00, max_rank=3, #ifun_evals=0, #ffun_evals=856
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1568
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1624
% =amen_cross= swp=1, max_dx=6.550e+00, max_rank=3, #ifun_evals=0, #ffun_evals=800
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1480
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1536
% =amen_cross= swp=1, max_dx=6.705e+00, max_rank=3, #ifun_evals=0, #ffun_evals=760
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1376
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1432
% =amen_cross= swp=1, max_dx=8.452e+00, max_rank=3, #ifun_evals=0, #ffun_evals=760
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1376
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1432
% =amen_cross= swp=1, max_dx=8.188e+00, max_rank=3, #ifun_evals=0, #ffun_evals=856
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1552
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1608
% =amen_cross= swp=1, max_dx=2.428e+01, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=1.312e-04, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=3.590e-14, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=1.625e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=2.462e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% =amen_cross= swp=1, max_dx=6.802e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=2.000e-02, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=8.787e-15, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=7.952e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=3.751e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% =amen_cross= swp=1, max_dx=7.912e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=1.109e-02, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=6.960e-15, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=7.280e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=3.962e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% Solution Error between TT and matrix= 7.13e-03
% Elapsed time of qtt = 0.86 seconds
