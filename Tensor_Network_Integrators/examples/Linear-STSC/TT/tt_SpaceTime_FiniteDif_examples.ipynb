% %%
addpath(genpath('../../../matlab/Linear-STSC/src/'))
addpath(genpath('../../../matlab/utils/chebfun/'))
addpath(genpath('../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../matlab/utils/ttfunc/'))
close all; clear;

% %%
%% load test cases
testname = 'ConstantCoeff'; %example 1 - constant coefficient
% testname = 'VariableCoeff'; %example 2 - variable coefficient
% testname = 'NonSmooth'; %example 3 - variable coefficient

fprintf('Working on testcase %s \n',testname);
load(sprintf('../testcases/%s.mat',testname));
%%
a = -1;
b = 1;
tol = 1e-10;
savefilename = sprintf('../plot_data/tt_ST_FD_%s.mat', testname);
%% now the time step is the same as space step
Ns = [4,6,8];
R = cell(numel(Ns),1);
for i = 1:numel(Ns)
  tic
  n = Ns(i);
  TN = n;
  SN = n-1;
  N1 = SN+1;

  %%
  [ttsol,Ctt] = tt_ST_FD_FD_3D_Solver(testcase,TN,SN,tol,a,b);
  tt_time = toc;
  %% check the error
  exacttt = amen_cross(Ctt, @(x) cross_fun_nD(x,testcase.exactfn),tol);
  exacttt = tt_get_inner(exacttt,{2:TN,2:N1-1,2:N1-1,2:N1-1});
  % exacttt = full(exacttt);
  Err = norm(ttsol-exacttt)/norm(exacttt);
  fprintf('Solution Error between TT and matrix= %.2e \n',...
    Err);

  fprintf('Elapsed time of qtt = %.2f seconds \n', tt_time)
  fprintf('Compression Ratio of ttsol = %.2e \n', compress_ratio_tt(ttsol));


  %% collect results
  c.sol = ttsol; %solution
  c.err = Err; % error
  c.time = tt_time; % elapsed_time
  R{i} = c;

  save(savefilename,'Ns','R','tol','testcase');
end
% Out:
% Working on testcase ConstantCoeff
% =amen_cross= swp=1, max_dx=5.667e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% amen-mm: swp=1{1}, max_dx=1.532e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=6.576e-16, max_r=6
% amen-mm: swp=1{1}, max_dx=1.500e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=9.129e-16, max_r=6
% =amen_cross= swp=1, max_dx=6.250e+00, max_rank=3, #ifun_evals=0, #ffun_evals=376
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=700
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=728
% =amen_cross= swp=1, max_dx=4.376e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% =amen_cross= swp=1, max_dx=4.490e+00, max_rank=2, #ifun_evals=0, #ffun_evals=304
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=576
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=604
% amen-mm: swp=1{1}, max_dx=1.726e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.006e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.798e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.564e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.414e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.564e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.470e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.220e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.417e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.861e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.799e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.220e-16, max_r=5
% =amen_cross= swp=1, max_dx=4.844e+00, max_rank=3, #ifun_evals=0, #ffun_evals=348
% =amen_cross= swp=2, max_dx=0.000e+00, max_rank=2, #ifun_evals=0, #ffun_evals=664
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=692
% amen-mm: swp=1{1}, max_dx=1.310e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.564e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.309e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.220e-16, max_r=5
% =amen_cross= swp=1, max_dx=1.867e+01, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=4.130e-05, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=1.344e-14, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=6.058e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=1.383e-14, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% =amen_cross= swp=1, max_dx=4.270e+00, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=1.549e-02, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=5.045e-15, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=2.062e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=5.488e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% amen-mv: swp=1{1}, max_dx=1.347e+00, max_r=5
% amen-mv: swp=1{0}, max_dx=8.364e-16, max_r=3
% Warning: MEX local solver is not found, disabled
% =amen_solve= sweep 1, max_dx: 1.686e+00, max_res: 1.980e+00, max_rank: 6
% =amen_solve= sweep 2, max_dx: 9.687e-16, max_res: 1.040e-15, max_rank: 6
% =amen_solve= sweep 3, max_dx: 1.029e-15, max_res: 1.224e-15, max_rank: 3
% =amen_cross= swp=1, max_dx=9.363e+00, max_rank=4, #ifun_evals=0, #ffun_evals=480
% =amen_cross= swp=2, max_dx=6.082e-04, max_rank=6, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=3, max_dx=4.807e-15, max_rank=7, #ifun_evals=0, #ffun_evals=2024
% =amen_cross= swp=4, max_dx=2.314e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2256
% =amen_cross= swp=5, max_dx=5.244e-15, max_rank=5, #ifun_evals=0, #ffun_evals=2448
% Solution Error between TT and matrix= 1.71e-02
% Elapsed time of qtt = 0.64 seconds
% Compression Ratio of ttsol = 1.79e+00
% =amen_cross= swp=1, max_dx=7.588e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1176
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1218
% amen-mm: swp=1{1}, max_dx=1.464e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=6.733e-16, max_r=6
% amen-mm: swp=1{1}, max_dx=1.388e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=1.425e-15, max_r=6
% =amen_cross= swp=1, max_dx=6.793e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1176
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1218
% =amen_cross= swp=1, max_dx=5.838e+00, max_rank=3, #ifun_evals=0, #ffun_evals=672
% =amen_cross= swp=2, max_dx=1.053e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1254
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1296
% =amen_cross= swp=1, max_dx=9.724e+00, max_rank=3, #ifun_evals=0, #ffun_evals=642
% =amen_cross= swp=2, max_dx=1.071e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1188
% =amen_cross= swp=3, max_dx=5.439e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1230
% amen-mm: swp=1{1}, max_dx=1.545e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=4.651e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.557e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.424e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.594e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.234e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.408e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=1.576e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.356e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=1.372e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.427e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=1.372e-16, max_r=5
% =amen_cross= swp=1, max_dx=5.495e+00, max_rank=3, #ifun_evals=0, #ffun_evals=570
% =amen_cross= swp=2, max_dx=1.538e-15, max_rank=3, #ifun_evals=0, #ffun_evals=1122
% =amen_cross= swp=3, max_dx=1.804e-15, max_rank=1, #ifun_evals=0, #ffun_evals=1170
% amen-mm: swp=1{1}, max_dx=1.341e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.234e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.436e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=1.388e-17, max_r=5
% =amen_cross= swp=1, max_dx=1.713e+01, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=1.288e-04, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=2.388e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=8.886e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=1.985e-14, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% =amen_cross= swp=1, max_dx=5.390e+00, max_rank=4, #ifun_evals=0, #ffun_evals=810
% =amen_cross= swp=2, max_dx=2.103e-02, max_rank=6, #ifun_evals=0, #ffun_evals=2238
% =amen_cross= swp=3, max_dx=1.262e-14, max_rank=7, #ifun_evals=0, #ffun_evals=3960
% =amen_cross= swp=4, max_dx=5.988e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4422
% =amen_cross= swp=5, max_dx=5.804e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4782
% amen-mv: swp=1{1}, max_dx=1.083e+00, max_r=6
% amen-mv: swp=1{0}, max_dx=1.122e-04, max_r=6
% amen-mv: swp=2{1}, max_dx=4.900e-05, max_r=10
% amen-mv: swp=2{0}, max_dx=8.065e-15, max_r=10
% Warning: MEX local solver is not found, disabled
% =amen_solve= sweep 1, max_dx: 1.451e+00, max_res: 1.438e+00, max_rank: 6
% =amen_solve= sweep 2, max_dx: 9.307e-03, max_res: 1.673e-02, max_rank: 10
% =amen_solve= sweep 3, max_dx: 7.730e-06, max_res: 1.847e-05, max_rank: 14
% =amen_solve= sweep 4, max_dx: 4.840e-12, max_res: 8.462e-12, max_rank: 14
% =amen_solve= sweep 5, max_dx: 4.365e-13, max_res: 2.466e-12, max_rank: 10
% =amen_cross= swp=1, max_dx=6.450e+00, max_rank=4, #ifun_evals=0, #ffun_evals=852
% =amen_cross= swp=2, max_dx=1.414e-02, max_rank=6, #ifun_evals=0, #ffun_evals=2376
% =amen_cross= swp=3, max_dx=1.392e-14, max_rank=7, #ifun_evals=0, #ffun_evals=4134
% =amen_cross= swp=4, max_dx=5.720e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4596
% =amen_cross= swp=5, max_dx=5.804e-15, max_rank=5, #ifun_evals=0, #ffun_evals=4956
% Solution Error between TT and matrix= 1.02e-02
% Elapsed time of qtt = 0.31 seconds
% Compression Ratio of ttsol = 1.25e+00
% =amen_cross= swp=1, max_dx=6.574e+00, max_rank=3, #ifun_evals=0, #ffun_evals=760
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1392
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1448
% amen-mm: swp=1{1}, max_dx=1.458e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=8.649e-16, max_r=6
% amen-mm: swp=1{1}, max_dx=1.476e+00, max_r=6
% amen-mm: swp=2{0}, max_dx=1.428e-15, max_r=6
% =amen_cross= swp=1, max_dx=7.950e+00, max_rank=3, #ifun_evals=0, #ffun_evals=896
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1640
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1696
% =amen_cross= swp=1, max_dx=8.437e+00, max_rank=3, #ifun_evals=0, #ffun_evals=856
% =amen_cross= swp=2, max_dx=4.351e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1552
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1608
% =amen_cross= swp=1, max_dx=6.074e+00, max_rank=3, #ifun_evals=0, #ffun_evals=760
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1392
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1448
% amen-mm: swp=1{1}, max_dx=1.343e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=2.333e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.347e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.792e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.484e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.792e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.527e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=4.180e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.506e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.331e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.413e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.587e-16, max_r=5
% =amen_cross= swp=1, max_dx=5.978e+00, max_rank=3, #ifun_evals=0, #ffun_evals=720
% =amen_cross= swp=2, max_dx=3.553e-15, max_rank=2, #ifun_evals=0, #ffun_evals=1288
% =amen_cross= swp=3, max_dx=2.937e-16, max_rank=1, #ifun_evals=0, #ffun_evals=1344
% amen-mm: swp=1{1}, max_dx=1.445e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.668e-16, max_r=5
% amen-mm: swp=1{1}, max_dx=1.372e+00, max_r=5
% amen-mm: swp=2{0}, max_dx=3.531e-16, max_r=5
% =amen_cross= swp=1, max_dx=3.161e+01, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=8.292e-05, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=2.458e-14, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=2.267e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=2.259e-14, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% =amen_cross= swp=1, max_dx=5.479e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=2.298e-04, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=7.428e-15, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=6.117e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=3.765e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% amen-mv: swp=1{1}, max_dx=1.132e+00, max_r=6
% amen-mv: swp=1{0}, max_dx=9.846e-05, max_r=6
% amen-mv: swp=2{1}, max_dx=8.952e-05, max_r=10
% amen-mv: swp=2{0}, max_dx=1.218e-15, max_r=10
% Warning: MEX local solver is not found, disabled
% =amen_solve= sweep 1, max_dx: 1.889e+00, max_res: 2.068e+00, max_rank: 6
% =amen_solve= sweep 2, max_dx: 1.377e-02, max_res: 2.943e-02, max_rank: 10
% =amen_solve= sweep 3, max_dx: 7.215e-06, max_res: 1.525e-05, max_rank: 14
% =amen_solve= sweep 4, max_dx: 1.029e-08, max_res: 4.148e-08, max_rank: 18
% =amen_solve= sweep 5, max_dx: 2.112e-11, max_res: 9.976e-11, max_rank: 21
% =amen_solve= sweep 6, max_dx: 1.982e-12, max_res: 2.288e-11, max_rank: 17
% =amen_cross= swp=1, max_dx=4.678e+00, max_rank=4, #ifun_evals=0, #ffun_evals=1216
% =amen_cross= swp=2, max_dx=1.853e-02, max_rank=6, #ifun_evals=0, #ffun_evals=3600
% =amen_cross= swp=3, max_dx=7.455e-15, max_rank=7, #ifun_evals=0, #ffun_evals=6424
% =amen_cross= swp=4, max_dx=7.577e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7080
% =amen_cross= swp=5, max_dx=6.524e-15, max_rank=5, #ifun_evals=0, #ffun_evals=7560
% Solution Error between TT and matrix= 7.13e-03
% Elapsed time of qtt = 0.27 seconds
% Compression Ratio of ttsol = 9.33e-01
