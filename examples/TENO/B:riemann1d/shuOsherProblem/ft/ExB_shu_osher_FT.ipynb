% %% [markdown]
% <h1> Tensor-Train TENO Scheme for Compressible Flows
% </h1>

% %% [markdown]
% Engin Danis;Duc Truong;Ismael Boureima;Oleg Korobkin;Kim Rasmussen;Boian Alexandrov

% %% [markdown]
% https://doi.org/10.2514/6.2025-0304

% %%
%% Info
% Example B   : Shu-Osher problem in full-tensor format
% Developer   : M. Engin Danis
% Notes       :
% It is recommended to run this script on terminal:
% (1) do: export TTTENOLIB=/path/of/TENO-paper
% (2) do: matlab -nodesktop -nojvm -nosplash -nodisplay -singleCompThread -r "try, run('ExB_shu_osher_FT.m'); catch err, disp(getReport(err)); end;exit;"
% This script writes 1d results (x, rho_ft, u_ft, p_ft) for each grid level under "results" directory, which can be used for postprocessing if needed.

addpath(genpath('../../../../../matlab/TENO/src/ft/'))
addpath(genpath('../../../../../matlab/TENO/src/misc/'))
addpath(genpath('../../../../../matlab/utils/tt-toolbox/'))
addpath(genpath('../../../../../matlab/utils/ttfunc/'))

% %%
%% set number of grid levels 
num_lvls = 4;
 
%% Input parameters to ftFDTenoSolver.m (Nx, Ny, Nz will be set later)
Tfinal    = 1.8;                                  % Final Time of the simulation   
dtOption  = 3;                                    % Time Stepping Option           
CFL       = 0.05;                                 % CFL Number for adaptive time-stepping
Neq       = 5;                                    % Number of equations 
N1d       = 50*(2.^linspace(1,num_lvls,num_lvls));% Number of cells in each direction
Lx        = 10;                                   % Domain length in the x-direction 
Ly        = 1;                                    % Domain length in the y-direction 
Lz        = 1;                                    % Domain length in the z-direction 
funFlux   = @F_euler3d;                           % Function handle for flux vector computation in each direction 
funEig    = @Eig_euler3d;                         % Function handle for computing eigenvalues of flux jacobian    
funInit   = @Q0;                                  % Function handle for initial conditions                        
funBC     = @BC;                                  % Function handle for boundary conditions                       
ReconChar = true;                                 % Flag to use characteristic decomposition (true or false) 
isSource  = false;                                % Flag to use user-defined "sourceTerm.m" to handle source terms    
gam       = 1.4;                                  % Ratio of specific heats (not used here, so it is left empty)
isConsErr = false;                                % Flag to calculate the local conservation error

%% For spead measurements, make sure to use only a single thread
maxNumCompThreads(1); 
fprintf("Using %d threads\n",maxNumCompThreads);

%% Setup arrays for speed measurement reporting
CPUtime   = zeros(num_lvls,1);

%% Set the path where results will be written. This directory will be created if needed
resultPath = "results";
if exist(resultPath, 'dir')
    cmd = "rm -rf "+resultPath;
    system(cmd);
end
mkdir(resultPath);

%% Run simulations for all grid levels
for lvl=1:length(N1d)
    %
    Nx = N1d(lvl);
    Ny = 1; % change this to Nx for at least 2d simulations
    Nz = 1; % change this to Nx for at least 2d simulations
    %
    fprintf("%s",repelem("-",70));fprintf("\n");
    fprintf("Starting to solve grid level=%d with Nx=%d Ny=%d Nz=%d\n",lvl,Nx,Ny,Nz);
    fprintf("%s",repelem("-",70));fprintf("\n");
    %
    data = ftFDTenoSolver(Tfinal, dtOption, CFL, Neq, Nx, Ny, Nz, Lx, Ly, Lz,...
                          funFlux, funEig, funInit, funBC, ReconChar, isSource, gam, isConsErr);
    % Set time spent by the solver
    CPUtime(lvl) = data.CPUtime;
    % Write data to file
    Q  = data.Q; % numerical result
    %
    rho = Q(1,:,1,1);
    u   = Q(2,:,1,1)./rho;
    p   = (gam-1)*(Q(5,:,1,1) - 0.5*rho.*u.^2);
    %
    fileID = fopen(sprintf("%s/u-lvl=%d.txt",resultPath,lvl),'w');
    %
    for i=1:Nx
        %
        fprintf(fileID,'%.15e\t%.15e\t%.15e\t%.15e\n',data.X(i,1,1),rho(i),u(i),p(i));
        %
    end
    fclose(fileID);
    %
    save_errors(resultPath+"/time.txt",CPUtime(1:lvl));
    %
    fprintf("\n");
end
%
fprintf("\n ------ ------------\n");
fprintf(" level | CPUtime (s)\n");
fprintf(" ------ ------------\n");
fprintf(" %5d | %10.4e\n",[(1:length(CPUtime))' CPUtime]');
fprintf("\n");
% Out:
% Using 1 threads
% ----------------------------------------------------------------------
% Starting to solve grid level=1 with Nx=100 Ny=1 Nz=1
% ----------------------------------------------------------------------
% Time Step= 0	 Time=0.00000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 1	 Time=0.00500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 2	 Time=0.01000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 3	 Time=0.01500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 4	 Time=0.02000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 5	 Time=0.02500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 6	 Time=0.03000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 7	 Time=0.03500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 8	 Time=0.04000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 9	 Time=0.04500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 10	 Time=0.05000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 11	 Time=0.05500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 12	 Time=0.06000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 13	 Time=0.06500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 14	 Time=0.07000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 15	 Time=0.07500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 16	 Time=0.08000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 17	 Time=0.08500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 18	 Time=0.09000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 19	 Time=0.09500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 20	 Time=0.10000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 21	 Time=0.10500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 22	 Time=0.11000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 23	 Time=0.11500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 24	 Time=0.12000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 25	 Time=0.12500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 26	 Time=0.13000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 27	 Time=0.13500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 28	 Time=0.14000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 29	 Time=0.14500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 30	 Time=0.15000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 31	 Time=0.15500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 32	 Time=0.16000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 33	 Time=0.16500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 34	 Time=0.17000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 35	 Time=0.17500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 36	 Time=0.18000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 37	 Time=0.18500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 38	 Time=0.19000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 39	 Time=0.19500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 40	 Time=0.20000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 41	 Time=0.20500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 42	 Time=0.21000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 43	 Time=0.21500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 44	 Time=0.22000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 45	 Time=0.22500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 46	 Time=0.23000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 47	 Time=0.23500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 48	 Time=0.24000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 49	 Time=0.24500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 50	 Time=0.25000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 51	 Time=0.25500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 52	 Time=0.26000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 53	 Time=0.26500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 54	 Time=0.27000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 55	 Time=0.27500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 56	 Time=0.28000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 57	 Time=0.28500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 58	 Time=0.29000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 59	 Time=0.29500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 60	 Time=0.30000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 61	 Time=0.30500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 62	 Time=0.31000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 63	 Time=0.31500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 64	 Time=0.32000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 65	 Time=0.32500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 66	 Time=0.33000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 67	 Time=0.33500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 68	 Time=0.34000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 69	 Time=0.34500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 70	 Time=0.35000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 71	 Time=0.35500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 72	 Time=0.36000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 73	 Time=0.36500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 74	 Time=0.37000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 75	 Time=0.37500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 76	 Time=0.38000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 77	 Time=0.38500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 78	 Time=0.39000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 79	 Time=0.39500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step=
	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 205	 Time=1.02500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 206	 Time=1.03000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 207	 Time=1.03500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 208	 Time=1.04000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 209	 Time=1.04500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 210	 Time=1.05000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 211	 Time=1.05500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 212	 Time=1.06000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 213	 Time=1.06500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 214	 Time=1.07000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 215	 Time=1.07500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 216	 Time=1.08000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 217	 Time=1.08500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 218	 Time=1.09000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 219	 Time=1.09500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 220	 Time=1.10000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 221	 Time=1.10500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 222	 Time=1.11000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 223	 Time=1.11500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 224	 Time=1.12000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 225	 Time=1.12500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 226	 Time=1.13000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 227	 Time=1.13500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 228	 Time=1.14000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 229	 Time=1.14500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 230	 Time=1.15000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 231	 Time=1.15500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 232	 Time=1.16000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 233	 Time=1.16500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 234	 Time=1.17000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 235	 Time=1.17500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 236	 Time=1.18000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 237	 Time=1.18500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 238	 Time=1.19000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 239	 Time=1.19500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 240	 Time=1.20000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 241	 Time=1.20500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 242	 Time=1.21000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 243	 Time=1.21500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 244	 Time=1.22000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 245	 Time=1.22500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 246	 Time=1.23000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 247	 Time=1.23500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 248	 Time=1.24000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 249	 Time=1.24500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 250	 Time=1.25000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 251	 Time=1.25500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 252	 Time=1.26000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 253	 Time=1.26500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 254	 Time=1.27000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 255	 Time=1.27500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 256	 Time=1.28000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 257	 Time=1.28500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 258	 Time=1.29000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 259	 Time=1.29500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 260	 Time=1.30000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 261	 Time=1.30500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 262	 Time=1.31000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 263	 Time=1.31500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 264	 Time=1.32000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 265	 Time=1.32500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 266	 Time=1.33000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 267	 Time=1.33500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 268	 Time=1.34000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 269	 Time=1.34500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 270	 Time=1.35000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 271	 Time=1.35500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 272	 Time=1.36000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 273	 Time=1.36500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 274	 Time=1.37000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 275	 Time=1.37500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 276	 Time=1.38000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 277	 Time=1.38500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 278	 Time=1.39000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 279	 Time=1.39500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 280	 Time=1.40000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 281	 Time=1.40500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 282	 Time=1.41000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 283	 Time=1.41500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 284	 Time=1.42000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 285	 Time=1.42500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 286	 Time=1.43000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 287	 Time=1.43500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 288	 Time=1.44000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 289	 Time=1.44500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 290	 Time=1.45000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 291	 Time=1.45500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 292	 Time=1.46000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 293	 Time=1.46500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 294	 Time=1.47000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 295	 Time=1.47500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 296	 Time=1.48000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 297	 Time=1.48500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 298	 Time=1.49000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 299	 Time=1.49500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 300	 Time=1.50000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 301	 Time=1.50500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 302	 Time=1.51000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 303	 Time=1.51500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 304	 Time=1.52000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 305	 Time=1.52500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 306	 Time=1.53000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 307	 Time=1.53500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 308	 Time=1.54000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 309	 Time=1.54500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 310	 Time=1.55000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 311	 Time=1.55500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 312	 Time=1.56000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 313	 Time=1.56500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 314	 Time=1.57000	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 315	 Time=1.57500	 dt=5.00000e-03	 max_eig=0.00e+00
% Time Step= 316
% IOPub message rate exceeded.
% The Jupyter server will temporarily stop sending output
% to the client in order to avoid crashing it.
% To change this limit, set the config variable
% `--ServerApp.iopub_msg_rate_limit`.
%
% Current values:
% ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
% ServerApp.rate_limit_window=3.0 (secs)
